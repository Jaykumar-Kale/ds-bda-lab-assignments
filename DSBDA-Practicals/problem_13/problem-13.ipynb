# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier

from sklearn.metrics import accuracy_score

# ---------------------------------------------------
# Define Column Names
# ---------------------------------------------------

column_names = [
    'age',
    'sex',
    'cp',
    'trestbps',
    'chol',
    'fbs',
    'restecg',
    'thalach',
    'exang',
    'oldpeak',
    'slope',
    'ca',
    'thal',
    'target'
]

# ---------------------------------------------------
# Load Dataset
# ---------------------------------------------------

df = pd.read_csv(
    "../datasets/HeartDisease/Cleavland.csv",
    header=None,
    names=column_names
)

# ---------------------------------------------------
# Display Dataset
# ---------------------------------------------------

print("\nFIRST 5 RECORDS")
print(df.head())

# ---------------------------------------------------
# Handle Missing Values
# ---------------------------------------------------

df.replace('?', np.nan, inplace=True)

df = df.dropna()

# ---------------------------------------------------
# Convert All Columns to Numeric
# ---------------------------------------------------

for col in df.columns:
    df[col] = pd.to_numeric(df[col])

# ---------------------------------------------------
# Display Dataset Info
# ---------------------------------------------------

print("\nDATASET INFO")
print(df.info())

# ---------------------------------------------------
# Separate Features and Target
# ---------------------------------------------------

X = df.drop('target', axis=1)

y = df['target']

# ---------------------------------------------------
# Feature Scaling
# ---------------------------------------------------

scaler = StandardScaler()

X_scaled = scaler.fit_transform(X)

# ---------------------------------------------------
# Train Test Split
# ---------------------------------------------------

X_train, X_test, y_train, y_test = train_test_split(
    X_scaled,
    y,
    test_size=0.2,
    random_state=42
)

# ---------------------------------------------------
# Logistic Regression Model
# ---------------------------------------------------

lr_model = LogisticRegression(max_iter=1000)

lr_model.fit(X_train, y_train)

lr_pred = lr_model.predict(X_test)

lr_accuracy = accuracy_score(y_test, lr_pred)

print("\nLOGISTIC REGRESSION ACCURACY")
print(lr_accuracy)

# ---------------------------------------------------
# kNN Model
# ---------------------------------------------------

knn_model = KNeighborsClassifier(n_neighbors=5)

knn_model.fit(X_train, y_train)

knn_pred = knn_model.predict(X_test)

knn_accuracy = accuracy_score(y_test, knn_pred)

print("\nkNN ACCURACY")
print(knn_accuracy)

# ---------------------------------------------------
# Accuracy Comparison
# ---------------------------------------------------

print("\nACCURACY COMPARISON")

print("Logistic Regression Accuracy :", lr_accuracy)

print("kNN Accuracy                 :", knn_accuracy)
# Out:
# FIRST 5 RECORDS
#     age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0  63.0  1.0  1.0     145.0  233.0  1.0      2.0    150.0    0.0      2.3
# 1  67.0  1.0  4.0     160.0  286.0  0.0      2.0    108.0    1.0      1.5
# 2  67.0  1.0  4.0     120.0  229.0  0.0      2.0    129.0    1.0      2.6
# 3  37.0  1.0  3.0     130.0  250.0  0.0      0.0    187.0    0.0      3.5
# 4  41.0  0.0  2.0     130.0  204.0  0.0      2.0    172.0    0.0      1.4
#
#    slope   ca thal  target
# 0    3.0  0.0  6.0       0
# 1    2.0  3.0  3.0       2
# 2    2.0  2.0  7.0       1
# 3    3.0  0.0  3.0       0
# 4    1.0  0.0  3.0       0
#
# DATASET INFO
# <class 'pandas.core.frame.DataFrame'>
# Index: 297 entries, 0 to 301
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       297 non-null    float64
#  1   sex       297 non-null    float64
#  2   cp        297 non-null    float64
#  3   trestbps  297 non-null    float64
#  4   chol      297 non-null    float64
#  5   fbs       297 non-null    float64
#  6   restecg   297 non-null    float64
#  7   thalach   297 non-null    float64
#  8   exang     297 non-null    float64
#  9   oldpeak   297 non-null    float64
#  10  slope     297 non-null    float64
#  11  ca        297 non-null    float64
#  12  thal      297 non-null    float64
#  13  target    297 non-null    int64
# dtypes: float64(13), int64(1)
# memory usage: 34.8 KB
# None
#
# LOGISTIC REGRESSION ACCURACY
# 0.6166666666666667
#
# kNN ACCURACY
# 0.6166666666666667
#
# ACCURACY COMPARISON
# Logistic Regression Accuracy : 0.6166666666666667
# kNN Accuracy                 : 0.6166666666666667
# /Users/jaykumarkale/jk-coding/development/ds-bda-lab-assignments/DSBDA-Practicals/venv/lib/python3.9/site-packages/sklearn/linear_model/_linear_loss.py:203: RuntimeWarning: divide by zero encountered in matmul
#   raw_prediction = X @ weights.T + intercept  # ndarray, likely C-contiguous
# /Users/jaykumarkale/jk-coding/development/ds-bda-lab-assignments/DSBDA-Practicals/venv/lib/python3.9/site-packages/sklearn/linear_model/_linear_loss.py:203: RuntimeWarning: overflow encountered in matmul
#   raw_prediction = X @ weights.T + intercept  # ndarray, likely C-contiguous
# /Users/jaykumarkale/jk-coding/development/ds-bda-lab-assignments/DSBDA-Practicals/venv/lib/python3.9/site-packages/sklearn/linear_model/_linear_loss.py:203: RuntimeWarning: invalid value encountered in matmul
#   raw_prediction = X @ weights.T + intercept  # ndarray, likely C-contiguous
# /Users/jaykumarkale/jk-coding/development/ds-bda-lab-assignments/DSBDA-Practicals/venv/lib/python3.9/site-packages/sklearn/linear_model/_linear_loss.py:336: RuntimeWarning: divide by zero encountered in matmul
#   grad[:, :n_features] = grad_pointwise.T @ X + l2_reg_strength * weights
# /Users/jaykumarkale/jk-coding/development/ds-bda-lab-assignments/DSBDA-Practicals/venv/lib/python3.9/site-packages/sklearn/linear_model/_linear_loss.py:336: RuntimeWarning: overflow encountered in matmul
#   grad[:, :n_features] = grad_pointwise.T @ X + l2_reg_strength * weights
# /Users/jaykumarkale/jk-coding/development/ds-bda-lab-assignments/DSBDA-Practicals/venv/lib/python3.9/site-packages/sklearn/linear_model/_linear_loss.py:336: RuntimeWarning: invalid value encountered in matmul
#   grad[:, :n_features] = grad_pointwise.T @ X + l2_reg_strength * weights
